# %% [markdown]
# ### Task 1: Ethiomart Data Ingestion and  Data Preprocessing

# %%
import os
import sys
import pandas as pd
import asyncio
# Get the current working directory
current_dir = os.getcwd()

# Append the parent directory to sys.path
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# ignore warrnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the TelegramScraper class from the file where it's defined
from scripts.telegram_data_scrap import TelegramScraper
from scripts.preprocess_text_data import  AmharicTextPreprocessor

# %% [markdown]
# ### Telegram Message Scraping

# %%
# List of channels to scrape
channels = ['qnashcom']

# Initialize the TelegramScraper instance
scraper = TelegramScraper()

# %%
# Define a function to run the asynchronous methods in the notebook
async def run_scraper():
    await scraper.connect()  # Connect to Telegram
    await scraper.fetch_messages(channels, message_limit=5000, output_file='telegram_messages.csv')  # Fetch messages
    await scraper.disconnect()  # Disconnect from Telegram

# %%
# Run the scraper asynchronously in the notebook
await run_scraper()
# Out:
# Invalid code. Please try again.
# Signed in successfully as  🐤£Gech-gra-gra 👫; remember to not break the ToS or you will risk an account ban!
# Connected to Telegram
# Joining and fetching messages from qnashcom...
# Saving message 4244 from qnashcom
# Saving message 4243 from qnashcom
# Saving message 4242 from qnashcom
# Saving message 4241 from qnashcom
# Saving message 4240 from qnashcom
# Saving message 4239 from qnashcom
# Saving message 4238 from qnashcom
# Saving message 4237 from qnashcom
# Saving message 4236 from qnashcom
# Saving message 4235 from qnashcom
# Saving message 4234 from qnashcom
# Saving message 4233 from qnashcom
# Saving message 4232 from qnashcom
# Saving message 4231 from qnashcom
# Saving message 4230 from qnashcom
# Saving message 4229 from qnashcom
# Saving message 4227 from qnashcom
# Saving message 4226 from qnashcom
# Saving message 4225 from qnashcom
# Saving message 4223 from qnashcom
# Saving message 4222 from qnashcom
# Saving message 4221 from qnashcom
# Saving message 4220 from qnashcom
# Saving message 4219 from qnashcom
# Saving message 4218 from qnashcom
# Saving message 4217 from qnashcom
# Saving message 4216 from qnashcom
# Saving message 4214 from qnashcom
# Saving message 4213 from qnashcom
# Saving message 4212 from qnashcom
# Saving message 4211 from qnashcom
# Saving message 4210 from qnashcom
# Saving message 4209 from qnashcom
# Saving message 4208 from qnashcom
# Saving message 4207 from qnashcom
# Saving message 4206 from qnashcom
# Saving message 4205 from qnashcom
# Saving message 4204 from qnashcom
# Saving message 4203 from qnashcom
# Saving message 4202 from qnashcom
# Saving message 4201 from qnashcom
# Saving message 4200 from qnashcom
# Saving message 4199 from qnashcom
# Saving message 4198 from qnashcom
# Saving message 4197 from qnashcom
# Saving message 4196 from qnashcom
# Saving message 4195 from qnashcom
# Saving message 4194 from qnashcom
# Saving message 4193 from qnashcom
# Saving message 4192 from qnashcom
# Saving message 4191 from qnashcom
# Saving message 4190 from qnashcom
# Saving message 4189 from qnashcom
# Saving message 4188 from qnashcom
# Saving message 4187 from qnashcom
# Saving message 4186 from qnashcom
# Saving message 4185 from qnashcom
# Saving message 4184 from qnashcom
# Saving message 4183 from qnashcom
# Saving message 4182 from qnashcom
# Saving message 4181 from qnashcom
# Saving message 4180 from qnashcom
# Saving message 4179 from qnashcom
# Saving message 4178 from qnashcom
# Saving message 4177 from qnashcom
# Saving message 4176 from qnashcom
# Saving message 4175 from qnashcom
# Saving message 4174 from qnashcom
# Saving message 4173 from qnashcom
# Saving message 4172 from qnashcom
# Saving message 4171 from qnashcom
# Saving message 4170 from qnashcom
# Saving message 4169 from qnashcom
# Saving message 4168 from qnashcom
# Saving message 4167 from qnashcom
# Saving message 4166 from qnashcom
# Saving message 4165 from qnashcom
# Saving message 4164 from qnashcom
# Saving message 4163 from qnashcom
# Saving message 4162 from qnashcom
# Saving message 4161 from qnashcom
# Saving message 4160 from qnashcom
# Saving message 4159 from qnashcom
# Saving message 4158 from qnashcom
# Saving message 4157 from qnashcom
# Saving message 4156 from qnashcom
# Saving message 4155 from qnashcom
# Saving message 4154 from qnashcom
# Saving message 4153 from qnashcom
# Saving message 4152 from qnashcom
# Saving message 4151 from qnashcom
# Saving message 4150 from qnashcom
# Saving message 4149 from qnashcom
# Saving message 4148 from qnashcom
# Saving message 4147 from qnashcom
# Saving message 4146 from qnashcom
# Saving message 4145 from qnashcom
# Saving message 4144 from qnashcom
# Saving message 4143 from qnashcom
# Saving message 4142 from qnashcom
# Saving message 4141 from qnashcom
# Saving message 4140 from qnashcom
# Saving message 4136 from qnashcom
# Saving message 4135 from qnashcom
# Saving message 4134 from qnashcom
# Saving message 4133 from qnashcom
# Saving message 4132 from qnashcom
# Saving message 4131 from qnashcom
# Saving message 4130 from qnashcom
# Saving message 4129 from qnashcom
# Saving message 4128 from qnashcom
# Saving message 4127 from qnashcom
# Saving message 4126 from qnashcom
# Saving message 4125 from qnashcom
# Saving message 4124 from qnashcom
# Saving message 4123 from qnashcom
# Saving message 4121 from qnashcom
# Saving message 4120 from qnashcom
# Saving message 4119 from qnashcom
# Saving message 4118 from qnashcom
# Saving message 4113 from qnashcom
# Saving message 4112 from qnashcom
# Saving message 4111 from qnashcom
# Saving message 4110 from qnashcom
# Saving message 4109 from qnashcom
# Saving message 4108 from qnashcom
# Saving message 4107 from qnashcom
# Saving message 4106 from qnashcom
# Saving message 4105 from qnashcom
# Saving message 4104 from qnashcom
# Saving message 4103 from qnashcom
# Saving message 4099 from qnashcom
# Saving message 4098 from qnashcom
# Saving message 4097 from qnashcom
# Saving message 4096 from qnashcom
# Saving message 4095 from qnashcom
# Saving message 4094 from qnashcom
# Saving message 4093 from qnashcom
# Saving message 4092 from qnashcom
# Saving message 4091 from qnashcom
# Saving message 4090 from qnashcom
# Saving message 4089 from qnashcom
# Saving message 4088 from qnashcom
# Saving message 4087 from qnashcom
# Saving message 4086 from qnashcom
# Saving message 4085 from qnashcom
# Saving message 4084 from qnashcom
# Saving message 4083 from qnashcom
# Saving message 4082 from qnashcom
# Saving message 4081 from qnashcom
# Saving message 4078 from qnashcom
# Saving message 4076 from qnashcom
# Saving message 4075 from qnashcom
# Saving message 4074 from qnashcom
# Saving message 4073 from qnashcom
# Saving message 4072 from qnashcom
# Saving message 4071 from qnashcom
# Saving message 4070 from qnashcom
# Saving message 4069 from qnashcom
# Saving message 4068 from qnashcom
# Saving message 4067 from qnashcom
# Saving message 4066 from qnashcom
# Saving message 4065 from qnashcom
# Saving message 4064 from qnashcom
# Saving message 4063 from qnashcom
# Saving message 4062 from qnashcom
# Saving message 4061 from qnashcom
# Saving message 4060 from qnashcom
# Saving message 4059 from qnashcom
# Saving message 4058 from qnashcom
# Saving message 4057 from qnashcom
# Saving message 4056 from qnashcom
# Saving message 4055 from qnashcom
# Saving message 4053 from qnashcom
# Saving message 4052 from qnashcom
# Saving message 4051 from qnashcom
# Saving message 4049 from qnashcom
# Saving message 4048 from qnashcom
# Saving message 4047 from qnashcom
# Saving message 4046 from qnashcom
# Saving message 4045 from qnashcom
# Saving message 4044 from qnashcom
# Saving message 4043 from qnashcom
# Saving message 4042 from qnashcom
# Saving message 4041 from qnashcom
# Saving message 4040 from qnashcom
# Saving message 4039 from qnashcom
# Saving message 4038 from qnashcom
# Saving message 4037 from qnashcom
# Saving message 4036 from qnashcom
# Saving message 4035 from qnashcom
# Saving message 4034 from qnashcom
# Saving message 4033 from qnashcom
# Saving message 4032 from qnashcom
# Saving message 4031 from qnashcom
# Saving message 4030 from qnashcom
# Saving message 4029 from qnashcom
# Saving message 4028 from qnashcom
# Saving message 4027 from qnashcom
# Saving message 4026 from qnashcom
# Saving message 4025 from qnashcom
# Saving message 4024 from qnashcom
# Saving message 4023 from qnashcom
# Saving message 4022 from qnashcom
# Saving message 4021 from qnashcom
# Saving message 4020 from qnashcom
# Saving message 4019 from qnashcom
# Saving message 4018 from qnashcom
# Saving message 4017 from qnashcom
# Saving message 4016 from qnashcom
# Saving message 4015 from qnashcom
# Saving message 4014 from qnashcom
# Saving message 4013 from qnashcom
# Saving message 4012 from qnashcom
# Saving message 4011 from qnashcom
# Saving message 4010 from qnashcom
# Saving message 4009 from qnashcom
# Saving message 4008 from qnashcom
# Saving message 4007 from qnashcom
# Saving message 4006 from qnashcom
# Saving message 4005 from qnashcom
# Saving message 4004 from qnashcom
# Saving message 4003 from qnashcom
# Saving message 4002 from qnashcom
# Saving message 4001 from qnashcom
# Saving message 4000 from qnashcom
# Saving message 3999 from qnashcom
# Saving message 3998 from qnashcom
# Saving message 3997 from qnashcom
# Saving message 3996 from qnashcom
# Saving message 3995 from qnashcom
# Saving message 3993 from qnashcom
# Saving message 3992 from qnashcom
# Saving message 3991 from qnashcom
# Saving message 3989 from qnashcom
# Saving message 3988 from qnashcom
# Saving message 3987 from qnashcom
# Saving message 3986 from qnashcom
# Saving message 3985 from qnashcom
# Saving message 3984 from qnashcom
# Saving message 3983 from qnashcom
# Saving message 3982 from qnashcom
# Saving message 3981 from qnashcom
# Saving message 3980 from qnashcom
# Saving message 3979 from qnashcom
# Saving message 3978 from qnashcom
# Saving message 3977 from qnashcom
# Saving message 3976 from qnashcom
# Saving message 3975 from qnashcom
# Saving message 3974 from qnashcom
# Saving message 3973 from qnashcom
# Saving message 3972 from qnashcom
# Saving message 3970 from qnashcom
# Saving message 3969 from qnashcom
# Saving message 3968 from qnashcom
# Saving message 3967 from qnashcom
# Saving message 3966 from qnashcom
# Saving message 3965 from qnashcom
# Saving message 3964 from qnashcom
# Saving message 3963 from qnashcom
# Saving message 3962 from qnashcom
# Saving message 3961 from qnashcom
# Saving message 3960 from qnashcom
# Saving message 3959 from qnashcom
# Saving message 3958 from qnashcom
# Saving message 3957 from qnashcom
# Saving message 3956 from qnashcom
# Saving message 3955 from qnashcom
# Saving message 3954 from qnashcom
# Saving message 3953 from qnashcom
# Saving message 3952 from qnashcom
# Saving message 3951 from qnashcom
# Saving message 3950 from qnashcom
# Saving message 3949 from qnashcom
# Saving message 3947 from qnashcom
# Saving message 3946 from qnashcom
# Saving message 3945 from qnashcom
# Saving message 3944 from qnashcom
# Saving message 3943 from qnashcom
# Saving message 3940 from qnashcom
# Saving message 3939 from qnashcom
# Saving message 3938 from qnashcom
# Saving message 3937 from qnashcom
# Saving message 3936 from qnashcom
# Saving message 3935 from qnashcom
# Saving message 3934 from qnashcom
# Saving message 3933 from qnashcom
# Saving message 3932 from qnashcom
# Saving message 3931 from qnashcom
# Saving message 3930 from qnashcom
# Saving message 3929 from qnashcom
# Saving message 3927 from qnashcom
# Saving message 3926 from qnashcom
# Saving message 3925 from qnashcom
# Saving message 3924 from qnashcom
# Saving message 3923 from qnashcom
# Saving message 3922 from qnashcom
# Saving message 3921 from qnashcom
# Saving message 3920 from qnashcom
# Saving message 3919 from qnashcom
# Saving message 3918 from qnashcom
# Saving message 3917 from qnashcom
# Saving message 3916 from qnashcom
# Saving message 3915 from qnashcom
# Saving message 3914 from qnashcom
# Saving message 3913 from qnashcom
# Saving message 3912 from qnashcom
# Saving message 3911 from qnashcom
# Saving message 3910 from qnashcom
# Saving message 3909 from qnashcom
# Saving message 3908 from qnashcom
# Saving message 3907 from qnashcom
# Saving message 3906 from qnashcom
# Saving message 3905 from qnashcom
# Saving message 3904 from qnashcom
# Saving message 3903 from qnashcom
# Saving message 3902 from qnashcom
# Saving message 3901 from qnashcom
# Saving message 3900 from qnashcom
# Saving message 3899 from qnashcom
# Saving message 3898 from qnashcom
# Saving message 3897 from qnashcom
# Saving message 3895 from qnashcom
# Saving message 3894 from qnashcom
# Saving message 3892 from qnashcom
# Saving message 3891 from qnashcom
# Saving message 3890 from qnashcom
# Saving message 3889 from qnashcom
# Saving message 3888 from qnashcom
# Saving message 3887 from qnashcom
# Saving message 3886 from qnashcom
# Saving message 3885 from qnashcom
# Saving message 3884 from qnashcom
# Saving message 3883 from qnashcom
# Saving message 3882 from qnashcom
# Saving message 3881 from qnashcom
# Saving message 3880 from qnashcom
# Saving message 3879 from qnashcom
# Saving message 3878 from qnashcom
# Saving message 3877 from qnashcom
# Saving message 3876 from qnashcom
# Saving message 3875 from qnashcom
# Saving message 3874 from qnashcom
# Saving message 3873 from qnashcom
# Saving message 3872 from qnashcom
# Saving message 3871 from qnashcom
# Saving message 3870 from qnashcom
# Saving message 3869 from qnashcom
# Saving message 3868 from qnashcom
# Saving message 3867 from qnashcom
# Saving message 3866 from qnashcom
# Saving message 3865 from qnashcom
# Saving message 3863 from qnashcom
# Saving message 3862 from qnashcom
# Saving message 3861 from qnashcom
# Saving message 3860 from qnashcom
# Saving message 3858 from qnashcom
# Saving message 3857 from qnashcom
# Saving message 3856 from qnashcom
# Saving message 3855 from qnashcom
# Saving message 3854 from qnashcom
# Saving message 3853 from qnashcom
# Saving message 3851 from qnashcom
# Saving message 3850 from qnashcom
# Saving message 3849 from qnashcom
# Saving message 3848 from qnashcom
# Saving message 3844 from qnashcom
# Saving message 3843 from qnashcom
# Saving message 3842 from qnashcom
# Saving message 3840 from qnashcom
# Saving message 3839 from qnashcom
# Saving message 3838 from qnashcom
# Saving message 3837 from qnashcom
# Saving message 3834 from qnashcom
# Saving message 3833 from qnashcom
# Saving message 3832 from qnashcom
# Saving message 3831 from qnashcom
# Saving message 3830 from qnashcom
# Saving message 3829 from qnashcom
# Saving message 3828 from qnashcom
# Saving message 3827 from qnashcom
# Saving message 3826 from qnashcom
# Saving message 3825 from qnashcom
# Saving message 3824 from qnashcom
# Saving message 3823 from qnashcom
# Saving message 3822 from qnashcom
# Saving message 3821 from qnashcom
# Saving message 3820 from qnashcom
# Saving message 3819 from qnashcom
# Saving message 3818 from qnashcom
# Saving message 3817 from qnashcom
# Saving message 3816 from qnashcom
# Saving message 3815 from qnashcom
# Saving message 3814 from qnashcom
# Saving message 3813 from qnashcom
# Saving message 3812 from qnashcom
# Saving message 3811 from qnashcom
# Saving message 3810 from qnashcom
# Saving message 3809 from qnashcom
# Saving message 3808 from qnashcom
# Saving message 3807 from qnashcom
# Saving message 3806 from qnashcom
# Saving message 3805 from qnashcom
# Saving message 3804 from qnashcom
# Saving message 3803 from qnashcom
# Saving message 3801 from qnashcom
# Saving message 3800 from qnashcom
# Saving message 3799 from qnashcom
# Saving message 3798 from qnashcom
# Saving message 3797 from qnashcom
# Saving message 3796 from qnashcom
# Saving message 3795 from qnashcom
# Saving message 3794 from qnashcom
# Saving message 3793 from qnashcom
# Saving message 3792 from qnashcom
# Saving message 3790 from qnashcom
# Saving message 3789 from qnashcom
# Saving message 3788 from qnashcom
# Saving message 3787 from qnashcom
# Saving message 3786 from qnashcom
# Saving message 3785 from qnashcom
# Saving message 3784 from qnashcom
# Saving message 3782 from qnashcom
# Saving message 3781 from qnashcom
# Saving message 3780 from qnashcom
# Saving message 3779 from qnashcom
# Saving message 3778 from qnashcom
# Saving message 3777 from qnashcom
# Saving message 3776 from qnashcom
# Saving message 3775 from qnashcom
# Saving message 3774 from qnashcom
# Saving message 3772 from qnashcom
# Saving message 3771 from qnashcom
# Saving message 3770 from qnashcom
# Saving message 3769 from qnashcom
# Saving message 3768 from qnashcom
# Saving message 3767 from qnashcom
# Saving message 3766 from qnashcom
# Saving message 3765 from qnashcom
# Saving message 3764 from qnashcom
# Saving message 3763 from qnashcom
# Saving message 3762 from qnashcom
# Saving message 3761 from qnashcom
# Saving message 3760 from qnashcom
# Saving message 3759 from qnashcom
# Saving message 3758 from qnashcom
# Saving message 3757 from qnashcom
# Saving message 3756 from qnashcom
# Saving message 3755 from qnashcom
# Saving message 3754 from qnashcom
# Saving message 3753 from qnashcom
# Saving message 3752 from qnashcom
# Saving message 3751 from qnashcom
# Saving message 3750 from qnashcom
# Saving message 3749 from qnashcom
# Saving message 3748 from qnashcom
# Saving message 3747 from qnashcom
# Saving message 3746 from qnashcom
# Saving message 3745 from qnashcom
# Saving message 3744 from qnashcom
# Saving message 3743 from qnashcom
# Saving message 3742 from qnashcom
# Saving message 3741 from qnashcom
# Saving message 3740 from qnashcom
# Saving message 3739 from qnashcom
# Saving message 3738 from qnashcom
# Saving message 3737 from qnashcom
# Saving message 3736 from qnashcom
# Saving message 3735 from qnashcom
# Saving message 3734 from qnashcom
# Saving message 3733 from qnashcom
# Saving message 3732 from qnashcom
# Saving message 3731 from qnashcom
# Saving message 3730 from qnashcom
# Saving message 3728 from qnashcom
# Saving message 3727 from qnashcom
# Saving message 3726 from qnashcom
# Saving message 3725 from qnashcom
# Saving message 3724 from qnashcom
# Saving message 3723 from qnashcom
# Saving message 3722 from qnashcom
# Saving message 3721 from qnashcom
# Saving message 3720 from qnashcom
# Saving message 3719 from qnashcom
# Saving message 3718 from qnashcom
# Saving message 3717 from qnashcom
# Saving message 3716 from qnashcom
# Saving message 3715 from qnashcom
# Saving message 3714 from qnashcom
# Saving message 3713 from qnashcom
# Saving message 3712 from qnashcom
# Saving message 3711 from qnashcom
# Saving message 3710 from qnashcom
# Saving message 3708 from qnashcom
# Saving message 3706 from qnashcom
# Saving message 3705 from qnashcom
# Saving message 3704 from qnashcom
# Saving message 3703 from qnashcom
# Saving message 3702 from qnashcom
# Saving message 3701 from qnashcom
# Saving message 3700 from qnashcom
# Saving message 3699 from qnashcom
# Saving message 3698 from qnashcom
# Saving message 3697 from qnashcom
# Saving message 3696 from qnashcom
# Saving message 3695 from qnashcom
# Saving message 3694 from qnashcom
# Saving message 3693 from qnashcom
# Saving message 3692 from qnashcom
# Saving message 3691 from qnashcom
# Saving message 3688 from qnashcom
# Saving message 3687 from qnashcom
# Saving message 3686 from qnashcom
# Saving message 3685 from qnashcom
# Saving message 3684 from qnashcom
# Saving message 3683 from qnashcom
# Saving message 3682 from qnashcom
# Saving message 3681 from qnashcom
# Saving message 3680 from qnashcom
# Saving message 3679 from qnashcom
# Saving message 3678 from qnashcom
# Saving message 3677 from qnashcom
# Saving message 3676 from qnashcom
# Saving message 3675 from qnashcom
# Saving message 3674 from qnashcom
# Saving message 3673 from qnashcom
# Saving message 3672 from qnashcom
# Saving message 3671 from qnashcom
# Saving message 3670 from qnashcom
# Saving message 3669 from qnashcom
# Saving message 3668 from qnashcom
# Saving message 3667 from qnashcom
# Saving message 3666 from qnashcom
# Saving message 3665 from qnashcom
# Saving message 3664 from qnashcom
# Saving message 3663 from qnashcom
# Saving message 3660 from qnashcom
# Saving message 3659 from qnashcom
# Saving message 3658 from qnashcom
# Saving message 3657 from qnashcom
# Saving message 3656 from qnashcom
# Saving message 3655 from qnashcom
# Saving message 3654 from qnashcom
# Saving message 3653 from qnashcom
# Saving message 3652 from qnashcom
# Saving message 3651 from qnashcom
# Saving message 3650 from qnashcom
# Saving message 3648 from qnashcom
# Saving message 3647 from qnashcom
# Saving message 3646 from qnashcom
# Saving message 3645 from qnashcom
# Saving message 3644 from qnashcom
# Saving message 3643 from qnashcom
# Saving message 3642 from qnashcom
# Saving message 3641 from qnashcom
# Saving message 3640 from qnashcom
# Saving message 3639 from qnashcom
# Saving message 3638 from qnashcom
# Saving message 3637 from qnashcom
# Saving message 3636 from qnashcom
# Saving message 3635 from qnashcom
# Saving message 3634 from qnashcom
# Saving message 3633 from qnashcom
# Saving message 3632 from qnashcom
# Saving message 3631 from qnashcom
# Saving message 3630 from qnashcom
# Saving message 3629 from qnashcom
# Saving message 3628 from qnashcom
# Saving message 3627 from qnashcom
# Saving message 3626 from qnashcom
# Saving message 3625 from qnashcom
# Saving message 3624 from qnashcom
# Saving message 3623 from qnashcom
# Saving message 3622 from qnashcom
# Saving message 3621 from qnashcom
# Saving message 3620 from qnashcom
# Saving message 3619 from qnashcom
# Saving message 3618 from qnashcom
# Saving message 3617 from qnashcom
# Saving message 3616 from qnashcom
# Saving message 3615 from qnashcom
# Saving message 3614 from qnashcom
# Saving message 3613 from qnashcom
# Saving message 3612 from qnashcom
# Saving message 3611 from qnashcom
# Saving message 3610 from qnashcom
# Saving message 3609 from qnashcom
# Saving message 3608 from qnashcom
# Saving message 3607 from qnashcom
# Saving message 3606 from qnashcom
# Saving message 3603 from qnashcom
# Saving message 3602 from qnashcom
# Saving message 3601 from qnashcom
# Saving message 3600 from qnashcom
# Saving message 3599 from qnashcom
# Saving message 3598 from qnashcom
# Saving message 3597 from qnashcom
# Saving message 3596 from qnashcom
# Saving message 3595 from qnashcom
# Saving message 3594 from qnashcom
# Saving message 3593 from qnashcom
# Saving message 3592 from qnashcom
# Saving message 3591 from qnashcom
# Saving message 3590 from qnashcom
# Saving message 3589 from qnashcom
# Saving message 3588 from qnashcom
# Saving message 3587 from qnashcom
# Saving message 3586 from qnashcom
# Saving message 3585 from qnashcom
# Saving message 3584 from qnashcom
# Saving message 3583 from qnashcom
# Saving message 3578 from qnashcom
# Saving message 3577 from qnashcom
# Saving message 3576 from qnashcom
# Saving message 3575 from qnashcom
# Saving message 3574 from qnashcom
# Saving message 3573 from qnashcom
# Saving message 3572 from qnashcom
# Saving message 3571 from qnashcom
# Saving message 3570 from qnashcom
# Saving message 3569 from qnashcom
# Saving message 3568 from qnashcom
# Saving message 3567 from qnashcom
# Saving message 3566 from qnashcom
# Saving message 3565 from qnashcom
# Saving message 3564 from qnashcom
# Saving message 3562 from qnashcom
# Saving message 3561 from qnashcom
# Saving message 3560 from qnashcom
# Saving message 3559 from qnashcom
# Saving message 3558 from qnashcom
# Saving message 3557 from qnashcom
# Saving message 3556 from qnashcom
# Saving message 3555 from qnashcom
# Saving message 3554 from qnashcom
# Saving message 3553 from qnashcom
# Saving message 3552 from qnashcom
# Saving message 3551 from qnashcom
# Saving message 3550 from qnashcom
# Saving message 3549 from qnashcom
# Saving message 3548 from qnashcom
# Saving message 3547 from qnashcom
# Saving message 3546 from qnashcom
# Saving message 3545 from qnashcom
# Saving message 3544 from qnashcom
# Saving message 3543 from qnashcom
# Saving message 3542 from qnashcom
# Saving message 3541 from qnashcom
# Saving message 3540 from qnashcom
# Saving message 3539 from qnashcom
# Saving message 3538 from qnashcom
# Saving message 3537 from qnashcom
# Saving message 3536 from qnashcom
# Saving message 3535 from qnashcom
# Saving message 3534 from qnashcom
# Saving message 3533 from qnashcom
# Saving message 3532 from qnashcom
# Saving message 3531 from qnashcom
# Saving message 3530 from qnashcom
# Saving message 3529 from qnashcom
# Saving message 3528 from qnashcom
# Saving message 3527 from qnashcom
# Saving message 3526 from qnashcom
# Saving message 3525 from qnashcom
# Saving message 3524 from qnashcom
# Saving message 3523 from qnashcom
# Saving message 3522 from qnashcom
# Saving message 3521 from qnashcom
# Saving message 3520 from qnashcom
# Saving message 3519 from qnashcom
# Saving message 3518 from qnashcom
# Saving message 3517 from qnashcom
# Saving message 3516 from qnashcom
# Saving message 3515 from qnashcom
# Saving message 3514 from qnashcom
# Saving message 3513 from qnashcom
# Saving message 3512 from qnashcom
# Saving message 3511 from qnashcom
# Saving message 3510 from qnashcom
# Saving message 3509 from qnashcom
# Saving message 3508 from qnashcom
# Saving message 3507 from qnashcom
# Saving message 3506 from qnashcom
# Saving message 3505 from qnashcom
# Saving message 3504 from qnashcom
# Saving message 3503 from qnashcom
# Saving message 3502 from qnashcom
# Saving message 3501 from qnashcom
# Saving message 3500 from qnashcom
# Saving message 3499 from qnashcom
# Saving message 3498 from qnashcom
# Saving message 3497 from qnashcom
# Saving message 3496 from qnashcom
# Saving message 3494 from qnashcom
# Saving message 3493 from qnashcom
# Saving message 3492 from qnashcom
# Saving message 3491 from qnashcom
# Saving message 3490 from qnashcom
# Saving message 3489 from qnashcom
# Saving message 3488 from qnashcom
# Saving message 3487 from qnashcom
# Saving message 3486 from qnashcom
# Saving message 3485 from qnashcom
# Saving message 3484 from qnashcom
# Saving message 3483 from qnashcom
# Saving message 3482 from qnashcom
# Saving message 3481 from qnashcom
# Saving message 3480 from qnashcom
# Saving message 3479 from qnashcom
# Saving message 3478 from qnashcom
# Saving message 3477 from qnashcom
# Saving message 3476 from qnashcom
# Saving message 3474 from qnashcom
# Saving message 3473 from qnashcom
# Saving message 3472 from qnashcom
# Saving message 3471 from qnashcom
# Saving message 3470 from qnashcom
# Saving message 3469 from qnashcom
# Saving message 3468 from qnashcom
# Saving message 3467 from qnashcom
# Saving message 3466 from qnashcom
# Saving message 3465 from qnashcom
# Saving message 3464 from qnashcom
# Saving message 3463 from qnashcom
# Saving message 3462 from qnashcom
# Saving message 3461 from qnashcom
# Saving message 3459 from qnashcom
# Saving message 3458 from qnashcom
# Saving message 3457 from qnashcom
# Saving message 3456 from qnashcom
# Saving message 3455 from qnashcom
# Saving message 3454 from qnashcom
# Saving message 3453 from qnashcom
# Saving message 3452 from qnashcom
# Saving message 3451 from qnashcom
# Saving message 3450 from qnashcom
# Saving message 3449 from qnashcom
# Saving message 3448 from qnashcom
# Saving message 3447 from qnashcom
# Saving message 3446 from qnashcom
# Saving message 3444 from qnashcom
# Saving message 3443 from qnashcom
# Saving message 3442 from qnashcom
# Saving message 3441 from qnashcom
# Saving message 3440 from qnashcom
# Saving message 3439 from qnashcom
# Saving message 3438 from qnashcom
# Saving message 3437 from qnashcom
# Saving message 3436 from qnashcom
# Saving message 3435 from qnashcom
# Saving message 3434 from qnashcom
# Saving message 3433 from qnashcom
# Saving message 3432 from qnashcom
# Saving message 3431 from qnashcom
# Saving message 3430 from qnashcom
# Saving message 3429 from qnashcom
# Saving message 3428 from qnashcom
# Saving message 3427 from qnashcom
# Saving message 3426 from qnashcom
# Saving message 3425 from qnashcom
# Saving message 3424 from qnashcom
# Saving message 3423 from qnashcom
# Saving message 3422 from qnashcom
# Saving message 3421 from qnashcom
# Saving message 3420 from qnashcom
# Saving message 3419 from qnashcom
# Saving message 3418 from qnashcom
# Saving message 3417 from qnashcom
# Saving message 3416 from qnashcom
# Saving message 3415 from qnashcom
# Saving message 3414 from qnashcom
# Saving message 3413 from qnashcom
# Saving message 3412 from qnashcom
# Saving message 3411 from qnashcom
# Saving message 3410 from qnashcom
# Saving message 3409 from qnashcom
# Saving message 3408 from qnashcom
# Saving message 3407 from qnashcom
# Saving message 3406 from qnashcom
# Saving message 3405 from qnashcom
# Saving message 3404 from qnashcom
# Saving message 3403 from qnashcom
# Saving message 3402 from qnashcom
# Saving message 3401 from qnashcom
# Saving message 3400 from qnashcom
# Saving message 3396 from qnashcom
# Saving message 3395 from qnashcom
# Saving message 3394 from qnashcom
# Saving message 3393 from qnashcom
# Saving message 3392 from qnashcom
# Saving message 3391 from qnashcom
# Saving message 3390 from qnashcom
# Saving message 3389 from qnashcom
# Saving message 3388 from qnashcom
# Saving message 3387 from qnashcom
# Saving message 3386 from qnashcom
# Saving message 3385 from qnashcom
# Saving message 3384 from qnashcom
# Saving message 3383 from qnashcom
# Saving message 3382 from qnashcom
# Saving message 3381 from qnashcom
# Saving message 3380 from qnashcom
# Saving message 3379 from qnashcom
# Saving message 3378 from qnashcom
# Saving message 3377 from qnashcom
# Saving message 3376 from qnashcom
# Saving message 3375 from qnashcom
# Saving message 3374 from qnashcom
# Saving message 3373 from qnashcom
# Saving message 3372 from qnashcom
# Saving message 3371 from qnashcom
# Saving message 3370 from qnashcom
# Saving message 3369 from qnashcom
# Saving message 3368 from qnashcom
# Saving message 3367 from qnashcom
# Saving message 3366 from qnashcom
# Saving message 3365 from qnashcom
# Saving message 3364 from qnashcom
# Saving message 3363 from qnashcom
# Saving message 3362 from qnashcom
# Saving message 3361 from qnashcom
# Saving message 3360 from qnashcom
# Saving message 3359 from qnashcom
# Saving message 3358 from qnashcom
# Saving message 3357 from qnashcom
# Saving message 3356 from qnashcom
# Saving message 3355 from qnashcom
# Saving message 3354 from qnashcom
# Saving message 3353 from qnashcom
# Saving message 3352 from qnashcom
# Saving message 3351 from qnashcom
# Saving message 3350 from qnashcom
# Saving message 3349 from qnashcom
# Saving message 3348 from qnashcom
# Saving message 3347 from qnashcom
# Saving message 3346 from qnashcom
# Saving message 3345 from qnashcom
# Saving message 3344 from qnashcom
# Saving message 3343 from qnashcom
# Saving message 3342 from qnashcom
# Saving message 3341 from qnashcom
# Saving message 3340 from qnashcom
# Saving message 3339 from qnashcom
# Saving message 3338 from qnashcom
# Saving message 3337 from qnashcom
# Saving message 3336 from qnashcom
# Saving message 3335 from qnashcom
# Saving message 3334 from qnashcom
# Saving message 3333 from qnashcom
# Saving message 3332 from qnashcom
# Saving message 3331 from qnashcom
# Saving message 3330 from qnashcom
# Saving message 3329 from qnashcom
# Saving message 3328 from qnashcom
# Saving message 3327 from qnashcom
# Saving message 3326 from qnashcom
# Saving message 3325 from qnashcom
# Saving message 3324 from qnashcom
# Saving message 3323 from qnashcom
# Saving message 3322 from qnashcom
# Saving message 3321 from qnashcom
# Saving message 3320 from qnashcom
# Saving message 3319 from qnashcom
# Saving message 3318 from qnashcom
# Saving message 3317 from qnashcom
# Saving message 3316 from qnashcom
# Saving message 3315 from qnashcom
# Saving message 3314 from qnashcom
# Saving message 3313 from qnashcom
# Saving message 3312 from qnashcom
# Saving message 3311 from qnashcom
# Saving message 3310 from qnashcom
# Saving message 3309 from qnashcom
# Saving message 3308 from qnashcom
# Saving message 3307 from qnashcom
# Saving message 3306 from qnashcom
# Saving message 3305 from qnashcom
# Saving message 3304 from qnashcom
# Saving message 3303 from qnashcom
# Saving message 3302 from qnashcom
# Saving message 3301 from qnashcom
# Saving message 3300 from qnashcom
# Saving message 3299 from qnashcom
# Saving message 3298 from qnashcom
# Saving message 3297 from qnashcom
# Saving message 3296 from qnashcom
# Saving message 3295 from qnashcom
# Saving message 3294 from qnashcom
# Saving message 3293 from qnashcom
# Saving message 3292 from qnashcom
# Saving message 3291 from qnashcom
# Saving message 3290 from qnashcom
# Saving message 3289 from qnashcom
# Saving message 3288 from qnashcom
# Saving message 3287 from qnashcom
# Saving message 3286 from qnashcom
# Saving message 3285 from qnashcom
# Saving message 3284 from qnashcom
# Saving message 3283 from qnashcom
# Saving message 3282 from qnashcom
# Saving message 3281 from qnashcom
# Saving message 3280 from qnashcom
# Saving message 3279 from qnashcom
# Saving message 3278 from qnashcom
# Saving message 3277 from qnashcom
# Saving message 3276 from qnashcom
# Saving message 3275 from qnashcom
# Saving message 3274 from qnashcom
# Saving message 3273 from qnashcom
# Saving message 3272 from qnashcom
# Saving message 3270 from qnashcom
# Saving message 3269 from qnashcom
# Saving message 3268 from qnashcom
# Saving message 3267 from qnashcom
# Saving message 3266 from qnashcom
# Saving message 3265 from qnashcom
# Saving message 3264 from qnashcom
# Saving message 3263 from qnashcom
# Saving message 3262 from qnashcom
# Saving message 3261 from qnashcom
# Saving message 3260 from qnashcom
# Saving message 3259 from qnashcom
# Saving message 3258 from qnashcom
# Saving message 3257 from qnashcom
# Saving message 3256 from qnashcom
# Saving message 3255 from qnashcom
# Saving message 3254 from qnashcom
# Saving message 3253 from qnashcom
# Saving message 3252 from qnashcom
# Saving message 3251 from qnashcom
# Saving message 3250 from qnashcom
# Saving message 3249 from qnashcom
# Saving message 3248 from qnashcom
# Saving message 3247 from qnashcom
# Saving message 3246 from qnashcom
# Saving message 3245 from qnashcom
# Saving message 3244 from qnashcom
# Saving message 3243 from qnashcom
# Saving message 3242 from qnashcom
# Saving message 3241 from qnashcom
# Saving message 3240 from qnashcom
# Saving message 3239 from qnashcom
# Saving message 3238 from qnashcom
# Saving message 3237 from qnashcom
# Saving message 3233 from qnashcom
# Saving message 3232 from qnashcom
# Saving message 3231 from qnashcom
# Saving message 3230 from qnashcom
# Saving message 3229 from qnashcom
# Saving message 3228 from qnashcom
# Saving message 3227 from qnashcom
# Saving message 3225 from qnashcom
# Saving message 3224 from qnashcom
# Saving message 3223 from qnashcom
# Saving message 3222 from qnashcom
# Saving message 3221 from qnashcom
# Saving message 3220 from qnashcom
# Saving message 3219 from qnashcom
# Saving message 3218 from qnashcom
# Saving message 3217 from qnashcom
# Saving message 3216 from qnashcom
# Saving message 3215 from qnashcom
# Saving message 3214 from qnashcom
# Saving message 3213 from qnashcom
# Saving message 3212 from qnashcom
# Saving message 3211 from qnashcom
# Saving message 3210 from qnashcom
# Saving message 3209 from qnashcom
# Saving message 3208 from qnashcom
# Saving message 3207 from qnashcom
# Saving message 3206 from qnashcom
# Saving message 3205 from qnashcom
# Saving message 3204 from qnashcom
# Saving message 3203 from qnashcom
# Saving message 3202 from qnashcom
# Saving message 3201 from qnashcom
# Saving message 3200 from qnashcom
# Saving message 3199 from qnashcom
# Saving message 3198 from qnashcom
# Saving message 3197 from qnashcom
# Saving message 3196 from qnashcom
# Saving message 3195 from qnashcom
# Saving message 3194 from qnashcom
# Saving message 3193 from qnashcom
# Saving message 3192 from qnashcom
# Saving message 3191 from qnashcom
# Saving message 3190 from qnashcom
# Saving message 3189 from qnashcom
# Saving message 3188 from qnashcom
# Saving message 3187 from qnashcom
# Saving message 3186 from qnashcom
# Saving message 3185 from qnashcom
# Saving message 3184 from qnashcom
# Saving message 3183 from qnashcom
# Saving message 3182 from qnashcom
# Saving message 3181 from qnashcom
# Saving message 3179 from qnashcom
# Saving message 3178 from qnashcom
# Saving message 3177 from qnashcom
# Saving message 3176 from qnashcom
# Saving message 3175 from qnashcom
# Saving message 3174 from qnashcom
# Saving message 3173 from qnashcom
# Saving message 3172 from qnashcom
# Saving message 3171 from qnashcom
# Saving message 3170 from qnashcom
# Saving message 3169 from qnashcom
# Saving message 3168 from qnashcom
# Saving message 3167 from qnashcom
# Saving message 3166 from qnashcom
# Saving message 3165 from qnashcom
# Saving message 3164 from qnashcom
# Saving message 3162 from qnashcom
# Saving message 3161 from qnashcom
# Saving message 3160 from qnashcom
# Saving message 3159 from qnashcom
# Saving message 3158 from qnashcom
# Saving message 3157 from qnashcom
# Saving message 3156 from qnashcom
# Saving message 3155 from qnashcom
# Saving message 3154 from qnashcom
# Saving message 3153 from qnashcom
# Saving message 3152 from qnashcom
# Saving message 3151 from qnashcom
# Saving message 3150 from qnashcom
# Saving message 3149 from qnashcom
# Saving message 3148 from qnashcom
# Saving message 3147 from qnashcom
# Saving message 3146 from qnashcom
# Saving message 3145 from qnashcom
# Saving message 3144 from qnashcom
# Saving message 3143 from qnashcom
# Saving message 3142 from qnashcom
# Saving message 3141 from qnashcom
# Saving message 3139 from qnashcom
# Saving message 3138 from qnashcom
# Saving message 3136 from qnashcom
# Saving message 3135 from qnashcom
# Saving message 3134 from qnashcom
# Saving message 3133 from qnashcom
# Saving message 3131 from qnashcom
# Saving message 3130 from qnashcom
# Saving message 3129 from qnashcom
# Saving message 3128 from qnashcom
# Saving message 3127 from qnashcom
# Saving message 3126 from qnashcom
# Saving message 3123 from qnashcom
# Saving message 3122 from qnashcom
# Saving message 3121 from qnashcom
# Saving message 3120 from qnashcom
# Saving message 3119 from qnashcom
# Saving message 3118 from qnashcom
# Saving message 3117 from qnashcom
# Saving message 3116 from qnashcom
# Saving message 3115 from qnashcom
# Saving message 3114 from qnashcom
# Saving message 3113 from qnashcom
# Saving message 3112 from qnashcom
# Saving message 3111 from qnashcom
# Saving message 3110 from qnashcom
# Saving message 3109 from qnashcom
# Saving message 3107 from qnashcom
# Saving message 3106 from qnashcom
# Saving message 3105 from qnashcom
# Saving message 3104 from qnashcom
# Saving message 3103 from qnashcom
# Saving message 3102 from qnashcom
# Saving message 3101 from qnashcom
# Saving message 3100 from qnashcom
# Saving message 3099 from qnashcom
# Saving message 3098 from qnashcom
# Saving message 3097 from qnashcom
# Saving message 3096 from qnashcom
# Saving message 3095 from qnashcom
# Saving message 3094 from qnashcom
# Saving message 3093 from qnashcom
# Saving message 3092 from qnashcom
# Saving message 3091 from qnashcom
# Saving message 3090 from qnashcom
# Saving message 3089 from qnashcom
# Saving message 3088 from qnashcom
# Saving message 3087 from qnashcom
# Saving message 3086 from qnashcom
# Saving message 3085 from qnashcom
# Saving message 3084 from qnashcom
# Saving message 3083 from qnashcom
# Saving message 3082 from qnashcom
# Saving message 3079 from qnashcom
# Saving message 3078 from qnashcom
# Saving message 3077 from qnashcom
# Saving message 3076 from qnashcom
# Saving message 3075 from qnashcom
# Saving message 3074 from qnashcom
# Saving message 3073 from qnashcom
# Saving message 3072 from qnashcom
# Saving message 3071 from qnashcom
# Saving message 3070 from qnashcom
# Saving message 3069 from qnashcom
# Saving message 3068 from qnashcom
# Saving message 3067 from qnashcom
# Saving message 3066 from qnashcom
# Saving message 3065 from qnashcom
# Saving message 3064 from qnashcom
# Saving message 3063 from qnashcom
# Saving message 3062 from qnashcom
# Saving message 3061 from qnashcom
# Saving message 3060 from qnashcom
# Saving message 3059 from qnashcom
# Saving message 3058 from qnashcom
# Saving message 3057 from qnashcom
# Saving message 3055 from qnashcom
# Saving message 3054 from qnashcom
# Saving message 3053 from qnashcom
# Saving message 3052 from qnashcom
# Saving message 3051 from qnashcom
# Saving message 3050 from qnashcom
# Saving message 3049 from qnashcom
# Saving message 3048 from qnashcom
# Saving message 3047 from qnashcom
# Saving message 3046 from qnashcom
# Saving message 3045 from qnashcom
# Saving message 3044 from qnashcom
# Saving message 3043 from qnashcom
# Saving message 3042 from qnashcom
# Saving message 3041 from qnashcom
# Saving message 3040 from qnashcom
# Saving message 3038 from qnashcom
# Saving message 3037 from qnashcom
# Saving message 3031 from qnashcom
# Saving message 3030 from qnashcom
# Saving message 3029 from qnashcom
# Saving message 3028 from qnashcom
# Saving message 3027 from qnashcom
# Saving message 3026 from qnashcom
# Saving message 3025 from qnashcom
# Saving message 3024 from qnashcom
# Saving message 3023 from qnashcom
# Saving message 3022 from qnashcom
# Saving message 3020 from qnashcom
# Saving message 3019 from qnashcom
# Saving message 3018 from qnashcom
# Saving message 3017 from qnashcom
# Saving message 3016 from qnashcom
# Saving message 3014 from qnashcom
# Saving message 3013 from qnashcom
# Saving message 3012 from qnashcom
# Saving message 3011 from qnashcom
# Saving message 3010 from qnashcom
# Saving message 3009 from qnashcom
# Saving message 3008 from qnashcom
# Saving message 3007 from qnashcom
# Saving message 3006 from qnashcom
# Saving message 3005 from qnashcom
# Saving message 3004 from qnashcom
# Saving message 3003 from qnashcom
# Saving message 3002 from qnashcom
# Saving message 3001 from qnashcom
# Saving message 3000 from qnashcom
# Saving message 2999 from qnashcom
# Saving message 2998 from qnashcom
# Saving message 2997 from qnashcom
# Saving message 2996 from qnashcom
# Saving message 2995 from qnashcom
# Saving message 2994 from qnashcom
# Saving message 2993 from qnashcom
# Saving message 2992 from qnashcom
# Saving message 2991 from qnashcom
# Saving message 2990 from qnashcom
# Saving message 2989 from qnashcom
# Saving message 2988 from qnashcom
# Saving message 2987 from qnashcom
# Saving message 2986 from qnashcom
# Saving message 2985 from qnashcom
# Saving message 2984 from qnashcom
# Saving message 2983 from qnashcom
# Saving message 2982 from qnashcom
# Saving message 2981 from qnashcom
# Saving message 2980 from qnashcom
# Saving message 2979 from qnashcom
# Saving message 2978 from qnashcom
# Saving message 2977 from qnashcom
# Saving message 2976 from qnashcom
# Saving message 2975 from qnashcom
# Saving message 2974 from qnashcom
# Saving message 2973 from qnashcom
# Saving message 2972 from qnashcom
# Saving message 2971 from qnashcom
# Saving message 2970 from qnashcom
# Saving message 2969 from qnashcom
# Saving message 2968 from qnashcom
# Saving message 2967 from qnashcom
# Saving message 2966 from qnashcom
# Saving message 2965 from qnashcom
# Saving message 2964 from qnashcom
# Saving message 2963 from qnashcom
# Saving message 2962 from qnashcom
# Saving message 2961 from qnashcom
# Saving message 2960 from qnashcom
# Saving message 2959 from qnashcom
# Saving message 2958 from qnashcom
# Saving message 2957 from qnashcom
# Saving message 2956 from qnashcom
# Saving message 2955 from qnashcom
# Saving message 2954 from qnashcom
# Saving message 2953 from qnashcom
# Saving message 2952 from qnashcom
# Saving message 2951 from qnashcom
# Saving message 2950 from qnashcom
# Saving message 2949 from qnashcom
# Saving message 2948 from qnashcom
# Saving message 2947 from qnashcom
# Saving message 2944 from qnashcom
# Saving message 2943 from qnashcom
# Saving message 2942 from qnashcom
# Saving message 2941 from qnashcom
# Saving message 2940 from qnashcom
# Saving message 2939 from qnashcom
# Saving message 2938 from qnashcom
# Saving message 2937 from qnashcom
# Saving message 2936 from qnashcom
# Saving message 2935 from qnashcom
# Saving message 2934 from qnashcom
# Saving message 2933 from qnashcom
# Saving message 2932 from qnashcom
# Saving message 2931 from qnashcom
# Saving message 2930 from qnashcom
# Saving message 2929 from qnashcom
# Saving message 2928 from qnashcom
# Saving message 2927 from qnashcom
# Saving message 2926 from qnashcom
# Saving message 2925 from qnashcom
# Saving message 2924 from qnashcom
# Saving message 2923 from qnashcom
# Saving message 2922 from qnashcom
# Saving message 2921 from qnashcom
# Saving message 2920 from qnashcom
# Saving message 2919 from qnashcom
# Saving message 2918 from qnashcom
# Saving message 2917 from qnashcom
# Saving message 2916 from qnashcom
# Saving message 2914 from qnashcom
# Saving message 2913 from qnashcom
# Saving message 2912 from qnashcom
# Saving message 2911 from qnashcom
# Saving message 2910 from qnashcom
# Saving message 2909 from qnashcom
# Saving message 2908 from qnashcom
# Saving message 2907 from qnashcom
# Saving message 2906 from qnashcom
# Saving message 2905 from qnashcom
# Saving message 2904 from qnashcom
# Saving message 2903 from qnashcom
# Saving message 2902 from qnashcom
# Saving message 2901 from qnashcom
# Saving message 2900 from qnashcom
# Saving message 2899 from qnashcom
# Saving message 2898 from qnashcom
# Saving message 2897 from qnashcom
# Saving message 2896 from qnashcom
# Saving message 2895 from qnashcom
# Saving message 2894 from qnashcom
# Saving message 2893 from qnashcom
# Saving message 2892 from qnashcom
# Saving message 2891 from qnashcom
# Saving message 2890 from qnashcom
# Saving message 2889 from qnashcom
# Saving message 2888 from qnashcom
# Saving message 2887 from qnashcom
# Saving message 2886 from qnashcom
# Saving message 2884 from qnashcom
# Saving message 2883 from qnashcom
# Saving message 2882 from qnashcom
# Saving message 2881 from qnashcom
# Saving message 2879 from qnashcom
# Saving message 2878 from qnashcom
# Saving message 2877 from qnashcom
# Saving message 2876 from qnashcom
# Saving message 2874 from qnashcom
# Saving message 2873 from qnashcom
# Saving message 2872 from qnashcom
# Saving message 2871 from qnashcom
# Saving message 2870 from qnashcom
# Saving message 2869 from qnashcom
# Saving message 2868 from qnashcom
# Saving message 2867 from qnashcom
# Saving message 2866 from qnashcom
# Saving message 2865 from qnashcom
# Saving message 2864 from qnashcom
# Saving message 2863 from qnashcom
# Saving message 2862 from qnashcom
# Saving message 2861 from qnashcom
# Saving message 2860 from qnashcom
# Saving message 2857 from qnashcom
# Saving message 2856 from qnashcom
# Saving message 2855 from qnashcom
# Saving message 2854 from qnashcom
# Saving message 2852 from qnashcom
# Saving message 2851 from qnashcom
# Saving message 2850 from qnashcom
# Saving message 2849 from qnashcom
# Saving message 2848 from qnashcom
# Saving message 2847 from qnashcom
# Saving message 2846 from qnashcom
# Saving message 2845 from qnashcom
# Saving message 2844 from qnashcom
# Saving message 2843 from qnashcom
# Saving message 2842 from qnashcom
# Saving message 2841 from qnashcom
# Saving message 2840 from qnashcom
# Saving message 2839 from qnashcom
# Saving message 2838 from qnashcom
# Saving message 2837 from qnashcom
# Saving message 2836 from qnashcom
# Saving message 2835 from qnashcom
# Saving message 2834 from qnashcom
# Saving message 2833 from qnashcom
# Saving message 2832 from qnashcom
# Saving message 2831 from qnashcom
# Saving message 2830 from qnashcom
# Saving message 2829 from qnashcom
# Saving message 2828 from qnashcom
# Saving message 2827 from qnashcom
# Saving message 2822 from qnashcom
# Saving message 2820 from qnashcom
# Saving message 2819 from qnashcom
# Saving message 2818 from qnashcom
# Saving message 2817 from qnashcom
# Saving message 2816 from qnashcom
# Saving message 2815 from qnashcom
# Saving message 2814 from qnashcom
# Saving message 2813 from qnashcom
# Saving message 2812 from qnashcom
# Saving message 2810 from qnashcom
# Saving message 2809 from qnashcom
# Saving message 2808 from qnashcom
# Saving message 2807 from qnashcom
# Saving message 2806 from qnashcom
# Saving message 2805 from qnashcom
# Saving message 2804 from qnashcom
# Saving message 2803 from qnashcom
# Saving message 2802 from qnashcom
# Saving message 2801 from qnashcom
# Saving message 2800 from qnashcom
# Saving message 2799 from qnashcom
# Saving message 2798 from qnashcom
# Saving message 2797 from qnashcom
# Saving message 2796 from qnashcom
# Saving message 2795 from qnashcom
# Saving message 2794 from qnashcom
# Saving message 2793 from qnashcom
# Saving message 2792 from qnashcom
# Saving message 2791 from qnashcom
# Saving message 2790 from qnashcom
# Saving message 2789 from qnashcom
# Saving message 2786 from qnashcom
# Saving message 2785 from qnashcom
# Saving message 2784 from qnashcom
# Saving message 2783 from qnashcom
# Saving message 2782 from qnashcom
# Saving message 2781 from qnashcom
# Saving message 2780 from qnashcom
# Saving message 2779 from qnashcom
# Saving message 2778 from qnashcom
# Saving message 2777 from qnashcom
# Saving message 2776 from qnashcom
# Saving message 2775 from qnashcom
# Saving message 2774 from qnashcom
# Saving message 2773 from qnashcom
# Saving message 2772 from qnashcom
# Saving message 2771 from qnashcom
# Saving message 2770 from qnashcom
# Saving message 2769 from qnashcom
# Saving message 2768 from qnashcom
# Saving message 2767 from qnashcom
# Saving message 2766 from qnashcom
# Saving message 2765 from qnashcom
# Saving message 2764 from qnashcom
# Saving message 2763 from qnashcom
# Saving message 2762 from qnashcom
# Saving message 2761 from qnashcom
# Saving message 2760 from qnashcom
# Saving message 2759 from qnashcom
# Saving message 2758 from qnashcom
# Saving message 2757 from qnashcom
# Saving message 2756 from qnashcom
# Saving message 2755 from qnashcom
# Saving message 2754 from qnashcom
# Saving message 2753 from qnashcom
# Saving message 2752 from qnashcom
# Saving message 2751 from qnashcom
# Saving message 2750 from qnashcom
# Saving message 2749 from qnashcom
# Saving message 2748 from qnashcom
# Saving message 2747 from qnashcom
# Saving message 2744 from qnashcom
# Saving message 2743 from qnashcom
# Saving message 2742 from qnashcom
# Saving message 2741 from qnashcom
# Saving message 2740 from qnashcom
# Saving message 2739 from qnashcom
# Saving message 2738 from qnashcom
# Saving message 2737 from qnashcom
# Saving message 2736 from qnashcom
# Saving message 2735 from qnashcom
# Saving message 2734 from qnashcom
# ...
# Saving message 985 from qnashcom
# Saving message 984 from qnashcom
# Saving message 975 from qnashcom
# Saving message 974 from qnashcom
# Saving message 973 from qnashcom
# Saving message 972 from qnashcom
# Saving message 971 from qnashcom
# Saving message 970 from qnashcom
# Saving message 969 from qnashcom
# Saving message 968 from qnashcom
# Saving message 967 from qnashcom
# Saving message 966 from qnashcom
# Saving message 965 from qnashcom
# Saving message 964 from qnashcom
# Saving message 962 from qnashcom
# Saving message 961 from qnashcom
# Saving message 960 from qnashcom
# Saving message 959 from qnashcom
# Saving message 958 from qnashcom
# Saving message 957 from qnashcom
# Saving message 956 from qnashcom
# Saving message 955 from qnashcom
# Saving message 954 from qnashcom
# Saving message 953 from qnashcom
# Saving message 952 from qnashcom
# Saving message 951 from qnashcom
# Saving message 950 from qnashcom
# Saving message 949 from qnashcom
# Saving message 948 from qnashcom
# Saving message 947 from qnashcom
# Saving message 946 from qnashcom
# Saving message 945 from qnashcom
# Saving message 943 from qnashcom
# Saving message 942 from qnashcom
# Saving message 941 from qnashcom
# Saving message 940 from qnashcom
# Saving message 937 from qnashcom
# Saving message 936 from qnashcom
# Saving message 933 from qnashcom
# Saving message 932 from qnashcom
# Saving message 931 from qnashcom
# Saving message 930 from qnashcom
# Saving message 929 from qnashcom
# Saving message 928 from qnashcom
# Saving message 927 from qnashcom
# Saving message 926 from qnashcom
# Saving message 925 from qnashcom
# Saving message 924 from qnashcom
# Saving message 923 from qnashcom
# Saving message 922 from qnashcom
# Saving message 921 from qnashcom
# Saving message 920 from qnashcom
# Saving message 919 from qnashcom
# Saving message 918 from qnashcom
# Saving message 917 from qnashcom
# Saving message 916 from qnashcom
# Saving message 915 from qnashcom
# Saving message 913 from qnashcom
# Saving message 912 from qnashcom
# Saving message 911 from qnashcom
# Saving message 910 from qnashcom
# Saving message 909 from qnashcom
# Saving message 908 from qnashcom
# Saving message 907 from qnashcom
# Saving message 906 from qnashcom
# Saving message 905 from qnashcom
# Saving message 904 from qnashcom
# Saving message 903 from qnashcom
# Saving message 902 from qnashcom
# Saving message 901 from qnashcom
# Saving message 900 from qnashcom
# Saving message 899 from qnashcom
# Saving message 898 from qnashcom
# Saving message 897 from qnashcom
# Saving message 896 from qnashcom
# Saving message 895 from qnashcom
# Saving message 894 from qnashcom
# Saving message 893 from qnashcom
# Saving message 892 from qnashcom
# Saving message 891 from qnashcom
# Saving message 890 from qnashcom
# Saving message 889 from qnashcom
# Saving message 888 from qnashcom
# Saving message 887 from qnashcom
# Saving message 886 from qnashcom
# Saving message 885 from qnashcom
# Saving message 884 from qnashcom
# Saving message 883 from qnashcom
# Saving message 882 from qnashcom
# Saving message 878 from qnashcom
# Saving message 877 from qnashcom
# Saving message 876 from qnashcom
# Saving message 875 from qnashcom
# Saving message 874 from qnashcom
# Saving message 873 from qnashcom
# Saving message 872 from qnashcom
# Saving message 871 from qnashcom
# Saving message 870 from qnashcom
# Saving message 869 from qnashcom
# Saving message 868 from qnashcom
# Saving message 867 from qnashcom
# Saving message 866 from qnashcom
# Saving message 865 from qnashcom
# Saving message 864 from qnashcom
# Saving message 863 from qnashcom
# Saving message 862 from qnashcom
# Saving message 861 from qnashcom
# Saving message 860 from qnashcom
# Saving message 859 from qnashcom
# Saving message 858 from qnashcom
# Saving message 857 from qnashcom
# Saving message 856 from qnashcom
# Saving message 855 from qnashcom
# Saving message 854 from qnashcom
# Saving message 853 from qnashcom
# Saving message 852 from qnashcom
# Saving message 848 from qnashcom
# Saving message 847 from qnashcom
# Saving message 846 from qnashcom
# Saving message 845 from qnashcom
# Saving message 844 from qnashcom
# Saving message 843 from qnashcom
# Saving message 842 from qnashcom
# Saving message 841 from qnashcom
# Saving message 840 from qnashcom
# Saving message 839 from qnashcom
# Saving message 838 from qnashcom
# Saving message 837 from qnashcom
# Saving message 836 from qnashcom
# Saving message 835 from qnashcom
# Saving message 834 from qnashcom
# Saving message 833 from qnashcom
# Saving message 832 from qnashcom
# Saving message 831 from qnashcom
# Saving message 830 from qnashcom
# Saving message 829 from qnashcom
# Saving message 828 from qnashcom
# Saving message 827 from qnashcom
# Saving message 826 from qnashcom
# Saving message 825 from qnashcom
# Saving message 824 from qnashcom
# Saving message 823 from qnashcom
# Saving message 822 from qnashcom
# Saving message 821 from qnashcom
# Saving message 820 from qnashcom
# Saving message 819 from qnashcom
# Saving message 818 from qnashcom
# Saving message 817 from qnashcom
# Saving message 816 from qnashcom
# Saving message 815 from qnashcom
# Saving message 814 from qnashcom
# Saving message 813 from qnashcom
# Saving message 812 from qnashcom
# Saving message 811 from qnashcom
# Saving message 810 from qnashcom
# Saving message 809 from qnashcom
# Saving message 808 from qnashcom
# Saving message 807 from qnashcom
# Saving message 806 from qnashcom
# Saving message 805 from qnashcom
# Saving message 804 from qnashcom
# Saving message 803 from qnashcom
# Saving message 802 from qnashcom
# Saving message 801 from qnashcom
# Saving message 800 from qnashcom
# Saving message 799 from qnashcom
# Saving message 798 from qnashcom
# Saving message 797 from qnashcom
# Saving message 796 from qnashcom
# Saving message 795 from qnashcom
# Saving message 794 from qnashcom
# Saving message 793 from qnashcom
# Saving message 791 from qnashcom
# Saving message 790 from qnashcom
# Saving message 789 from qnashcom
# Saving message 788 from qnashcom
# Saving message 787 from qnashcom
# Saving message 786 from qnashcom
# Saving message 785 from qnashcom
# Saving message 784 from qnashcom
# Saving message 783 from qnashcom
# Saving message 782 from qnashcom
# Saving message 781 from qnashcom
# Saving message 780 from qnashcom
# Saving message 779 from qnashcom
# Saving message 778 from qnashcom
# Saving message 777 from qnashcom
# Saving message 776 from qnashcom
# Saving message 775 from qnashcom
# Saving message 774 from qnashcom
# Saving message 773 from qnashcom
# Saving message 772 from qnashcom
# Saving message 771 from qnashcom
# Saving message 770 from qnashcom
# Saving message 769 from qnashcom
# Saving message 768 from qnashcom
# Saving message 767 from qnashcom
# Saving message 766 from qnashcom
# Saving message 765 from qnashcom
# Saving message 764 from qnashcom
# Saving message 763 from qnashcom
# Saving message 762 from qnashcom
# Saving message 761 from qnashcom
# Saving message 760 from qnashcom
# Saving message 759 from qnashcom
# Saving message 758 from qnashcom
# Saving message 757 from qnashcom
# Saving message 756 from qnashcom
# Saving message 755 from qnashcom
# Saving message 754 from qnashcom
# Saving message 753 from qnashcom
# Saving message 752 from qnashcom
# Saving message 751 from qnashcom
# Saving message 750 from qnashcom
# Saving message 749 from qnashcom
# Saving message 748 from qnashcom
# Saving message 747 from qnashcom
# Saving message 746 from qnashcom
# Saving message 745 from qnashcom
# Saving message 744 from qnashcom
# Saving message 743 from qnashcom
# Saving message 742 from qnashcom
# Saving message 741 from qnashcom
# Saving message 740 from qnashcom
# Saving message 739 from qnashcom
# Saving message 738 from qnashcom
# Saving message 737 from qnashcom
# Saving message 736 from qnashcom
# Saving message 735 from qnashcom
# Saving message 734 from qnashcom
# Saving message 733 from qnashcom
# Saving message 732 from qnashcom
# Saving message 730 from qnashcom
# Saving message 729 from qnashcom
# Saving message 728 from qnashcom
# Saving message 727 from qnashcom
# Saving message 726 from qnashcom
# Saving message 725 from qnashcom
# Saving message 724 from qnashcom
# Saving message 723 from qnashcom
# Saving message 722 from qnashcom
# Saving message 721 from qnashcom
# Saving message 720 from qnashcom
# Saving message 719 from qnashcom
# Saving message 718 from qnashcom
# Saving message 717 from qnashcom
# Saving message 715 from qnashcom
# Saving message 713 from qnashcom
# Saving message 712 from qnashcom
# Saving message 711 from qnashcom
# Saving message 710 from qnashcom
# Saving message 709 from qnashcom
# Saving message 708 from qnashcom
# Saving message 707 from qnashcom
# Saving message 706 from qnashcom
# Saving message 705 from qnashcom
# Saving message 702 from qnashcom
# Saving message 701 from qnashcom
# Saving message 700 from qnashcom
# Saving message 699 from qnashcom
# Saving message 698 from qnashcom
# Saving message 697 from qnashcom
# Saving message 696 from qnashcom
# Saving message 695 from qnashcom
# Saving message 694 from qnashcom
# Saving message 693 from qnashcom
# Saving message 692 from qnashcom
# Saving message 691 from qnashcom
# Saving message 690 from qnashcom
# Saving message 689 from qnashcom
# Saving message 687 from qnashcom
# Saving message 686 from qnashcom
# Saving message 685 from qnashcom
# Saving message 684 from qnashcom
# Saving message 683 from qnashcom
# Saving message 682 from qnashcom
# Saving message 681 from qnashcom
# Saving message 680 from qnashcom
# Saving message 679 from qnashcom
# Saving message 678 from qnashcom
# Saving message 677 from qnashcom
# Saving message 676 from qnashcom
# Saving message 675 from qnashcom
# Saving message 674 from qnashcom
# Saving message 673 from qnashcom
# Saving message 672 from qnashcom
# Saving message 671 from qnashcom
# Saving message 669 from qnashcom
# Saving message 668 from qnashcom
# Saving message 667 from qnashcom
# Saving message 666 from qnashcom
# Saving message 665 from qnashcom
# Saving message 664 from qnashcom
# Saving message 663 from qnashcom
# Saving message 662 from qnashcom
# Saving message 660 from qnashcom
# Saving message 659 from qnashcom
# Saving message 658 from qnashcom
# Saving message 657 from qnashcom
# Saving message 646 from qnashcom
# Saving message 645 from qnashcom
# Saving message 644 from qnashcom
# Saving message 643 from qnashcom
# Saving message 642 from qnashcom
# Saving message 640 from qnashcom
# Saving message 639 from qnashcom
# Saving message 638 from qnashcom
# Saving message 636 from qnashcom
# Saving message 635 from qnashcom
# Saving message 634 from qnashcom
# Saving message 633 from qnashcom
# Saving message 632 from qnashcom
# Saving message 631 from qnashcom
# Saving message 630 from qnashcom
# Saving message 629 from qnashcom
# Saving message 628 from qnashcom
# Saving message 627 from qnashcom
# Saving message 626 from qnashcom
# Saving message 625 from qnashcom
# Saving message 624 from qnashcom
# Saving message 623 from qnashcom
# Saving message 619 from qnashcom
# Saving message 618 from qnashcom
# Saving message 616 from qnashcom
# Saving message 615 from qnashcom
# Saving message 614 from qnashcom
# Saving message 613 from qnashcom
# Saving message 612 from qnashcom
# Saving message 601 from qnashcom
# Saving message 600 from qnashcom
# Saving message 599 from qnashcom
# Saving message 598 from qnashcom
# Saving message 597 from qnashcom
# Saving message 596 from qnashcom
# Saving message 595 from qnashcom
# Saving message 592 from qnashcom
# Saving message 591 from qnashcom
# Saving message 590 from qnashcom
# Saving message 587 from qnashcom
# Saving message 586 from qnashcom
# Saving message 585 from qnashcom
# Saving message 584 from qnashcom
# Saving message 583 from qnashcom
# Saving message 581 from qnashcom
# Saving message 580 from qnashcom
# Saving message 579 from qnashcom
# Saving message 577 from qnashcom
# Saving message 575 from qnashcom
# Saving message 574 from qnashcom
# Saving message 573 from qnashcom
# Saving message 572 from qnashcom
# Saving message 569 from qnashcom
# Saving message 568 from qnashcom
# Saving message 567 from qnashcom
# Saving message 566 from qnashcom
# Saving message 565 from qnashcom
# Saving message 564 from qnashcom
# Saving message 563 from qnashcom
# Saving message 560 from qnashcom
# Saving message 559 from qnashcom
# Saving message 550 from qnashcom
# Saving message 549 from qnashcom
# Saving message 548 from qnashcom
# Saving message 537 from qnashcom
# Saving message 536 from qnashcom
# Saving message 527 from qnashcom
# Saving message 526 from qnashcom
# Saving message 505 from qnashcom
# Saving message 504 from qnashcom
# Saving message 503 from qnashcom
# Saving message 502 from qnashcom
# Saving message 501 from qnashcom
# Saving message 493 from qnashcom
# Saving message 492 from qnashcom
# Saving message 491 from qnashcom
# Saving message 490 from qnashcom
# Saving message 489 from qnashcom
# Saving message 487 from qnashcom
# Saving message 485 from qnashcom
# Saving message 484 from qnashcom
# Saving message 483 from qnashcom
# Saving message 482 from qnashcom
# Saving message 481 from qnashcom
# Saving message 468 from qnashcom
# Saving message 467 from qnashcom
# Saving message 466 from qnashcom
# Saving message 465 from qnashcom
# Saving message 464 from qnashcom
# Saving message 463 from qnashcom
# Saving message 462 from qnashcom
# Saving message 461 from qnashcom
# Saving message 460 from qnashcom
# Saving message 459 from qnashcom
# Saving message 456 from qnashcom
# Saving message 455 from qnashcom
# Saving message 454 from qnashcom
# Saving message 437 from qnashcom
# Saving message 436 from qnashcom
# Saving message 418 from qnashcom
# Saving message 417 from qnashcom
# Saving message 413 from qnashcom
# Saving message 411 from qnashcom
# Saving message 404 from qnashcom
# Saving message 402 from qnashcom
# Saving message 378 from qnashcom
# Saving message 377 from qnashcom
# Saving message 376 from qnashcom
# Saving message 371 from qnashcom
# Saving message 370 from qnashcom
# Saving message 367 from qnashcom
# Saving message 360 from qnashcom
# Saving message 352 from qnashcom
# Saving message 351 from qnashcom
# Saving message 343 from qnashcom
# Saving message 341 from qnashcom
# Saving message 340 from qnashcom
# Saving message 339 from qnashcom
# Saving message 338 from qnashcom
# Saving message 327 from qnashcom
# Saving message 326 from qnashcom
# Saving message 324 from qnashcom
# Saving message 322 from qnashcom
# Saving message 321 from qnashcom
# Saving message 314 from qnashcom
# Saving message 304 from qnashcom
# Saving message 303 from qnashcom
# Saving message 301 from qnashcom
# Saving message 277 from qnashcom
# Saving message 264 from qnashcom
# Saving message 191 from qnashcom
# Saving message 181 from qnashcom
# Saving message 180 from qnashcom
# Saving message 164 from qnashcom
# Saving message 162 from qnashcom
# Saving message 161 from qnashcom
# Saving message 139 from qnashcom
# Saving message 138 from qnashcom
# Saving message 137 from qnashcom
# Saving message 132 from qnashcom
# Saving message 131 from qnashcom
# Saving message 128 from qnashcom
# Saving message 66 from qnashcom
# Saving message 64 from qnashcom
# Saving message 62 from qnashcom
# Saving message 60 from qnashcom
# Saving message 59 from qnashcom
# Saving message 58 from qnashcom
# Saving message 56 from qnashcom
# Saving message 55 from qnashcom
# Saving message 54 from qnashcom
# Saving message 53 from qnashcom
# Saving message 52 from qnashcom
# Saving message 51 from qnashcom
# Saving message 50 from qnashcom
# Saving message 49 from qnashcom
# Saving message 48 from qnashcom
# Saving message 47 from qnashcom
# Saving message 45 from qnashcom
# Saving message 43 from qnashcom
# Saving message 42 from qnashcom
# Saving message 41 from qnashcom
# Saving message 40 from qnashcom
# Saving message 39 from qnashcom
# Saving message 38 from qnashcom
# Saving message 37 from qnashcom
# Saving message 36 from qnashcom
# Saving message 35 from qnashcom
# Saving message 34 from qnashcom
# Saving message 33 from qnashcom
# Saving message 32 from qnashcom
# Saving message 31 from qnashcom
# Saving message 30 from qnashcom
# Saving message 29 from qnashcom
# Saving message 28 from qnashcom
# Saving message 27 from qnashcom
# Saving message 25 from qnashcom
# Saving message 23 from qnashcom
# Saving message 22 from qnashcom
# Saving message 20 from qnashcom
# Saving message 19 from qnashcom
# Saving message 18 from qnashcom
# Saving message 17 from qnashcom
# Saving message 1 from qnashcom
# Finished fetching messages and saved to telegram_messages.csv.
# Disconnected from Telegram

# %%
# Read downloded CSV data into dataFrame
telegram_data = pd.read_csv('../Data/telegram_data_qnashcom.csv')

# %% [markdown]
# ### Text Preprocessing

# %% [markdown]
# ##### Initialization: Create an instance of the AmharicTextPreprocessor class.

# %%
text_processor = AmharicTextPreprocessor()

# %%
# Apply preprocessing to 'Message' column
telegram_data['Preprocessed_Message'] = telegram_data['Message'].apply(text_processor.preprocess_text)

# Display the preprocessed data
telegram_data[['Message', 'Preprocessed_Message']]
# Out:
#                                                 Message  \
# 0     🔥**2 ሊትር  ፔርሙስ**\nለቤት  ለቢሮ  ለሆቴል አገልግሎት መዋል የሚ...
# 1     📌🦴 Knife ቢላ \n\n☄️ High Quality \n\n🥩የስጋ, 🦴 የአ...
# 2     📌 2 PCs Silicon Brush Spatula\n\n⚡️ አንድ ብሩሽ እና...
# 3     📌 2 PCs Silicon Brush Spatula\n\n⚡️ አንድ ብሩሽ እና...
# 4     📣💪 **Alumunium Cloth Drying Stand**\n\n👕 የልብስ ...
# ...                                                 ...
# 3438  👔የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር \n  -የራሱ መቆጣ...
# 3439  🚫ቤትዎን ከአይጥ 🐀 ከበረሮ🕷 እና ከተባይ🐜 🚫\n               ...
# 3440  😍  ታላቅ ቅናሽ 😍\nዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ\n...
# 3441                                                NaN
# 3442                                                NaN
#
#                                    Preprocessed_Message
# 0     2 ሊትር ፔርሙስ ለቤት ለቢሮ ለሆቴል አገልግሎት መዋል የሚችሉ አሪፍ ፔር...
# 1     ቢላ ️ የስጋ የአጥንት 1000 ብር ለማዘዝ ውስን ፍሬ ነው የቀረው ጥራት...
# 2     2 ️ አንድ ብሩሽ እና አንድ ስፓቹላ ዋጋ 300 ብር ለማዘዝ ውስን ፍሬ ...
# 3     2 ️ አንድ ብሩሽ እና አንድ ስፓቹላ ዋጋ 300 ብር ውስን ፍሬ ነው የቀ...
# 4     የልብስ ማስጪያ ከአልሙኒየም የተሰራ የሚተጣጠፍ ለማስቀመጥ ቦታ የማይዝ ዋ...
# ...                                                 ...
# 3438  የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር የራሱ መቆጣጠሪያ ያለ...
# 3439  ቤትዎን ከአይጥ ከበረሮ እና ከተባይ ነፃ ያድርጉ በቀላሉ በማንኛውም ሶኬት...
# 3440  ታላቅ ቅናሽ ዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ ባለ ዘጠኝ ...
# 3441
# 3442
#
# [3443 rows x 2 columns]

# %%
# filter Not null values from message columns
telegram_data = telegram_data[telegram_data['Preprocessed_Message']!=("")]
telegram_data
# Out:
#        channel  message_id                       date         sender  \
# 0     qnashcom        4241  2024-09-26T06:29:40+00:00 -1001336267238
# 1     qnashcom        4240  2024-09-24T06:46:47+00:00 -1001336267238
# 2     qnashcom        4239  2024-09-23T16:11:57+00:00 -1001336267238
# 3     qnashcom        4238  2024-09-23T13:40:32+00:00 -1001336267238
# 4     qnashcom        4237  2024-09-23T08:23:24+00:00 -1001336267238
# ...        ...         ...                        ...            ...
# 3436  qnashcom          23  2020-08-26T03:25:39+00:00 -1001336267238
# 3437  qnashcom          22  2020-08-26T02:55:07+00:00 -1001336267238
# 3438  qnashcom          20  2020-08-26T02:44:03+00:00 -1001336267238
# 3439  qnashcom          19  2020-08-26T02:32:16+00:00 -1001336267238
# 3440  qnashcom          18  2020-08-26T02:16:56+00:00 -1001336267238
#
#                                                 Message                 media  \
# 0     🔥**2 ሊትር  ፔርሙስ**\nለቤት  ለቢሮ  ለሆቴል አገልግሎት መዋል የሚ...     MessageMediaPhoto
# 1     📌🦴 Knife ቢላ \n\n☄️ High Quality \n\n🥩የስጋ, 🦴 የአ...     MessageMediaPhoto
# 2     📌 2 PCs Silicon Brush Spatula\n\n⚡️ አንድ ብሩሽ እና...     MessageMediaPhoto
# 3     📌 2 PCs Silicon Brush Spatula\n\n⚡️ አንድ ብሩሽ እና...  MessageMediaDocument
# 4     📣💪 **Alumunium Cloth Drying Stand**\n\n👕 የልብስ ...     MessageMediaPhoto
# ...                                                 ...                   ...
# 3436  😍አስደሳች ዜና 😍\nFoot bath massager\n😫ብዙ ጊዜ በስራ ላይ...     MessageMediaPhoto
# 3437  😍አስደሳች ዜና 😍\n\nCerotti የፀጉር ማድረቂያ\n\n♨️በጣልያን የ...     MessageMediaPhoto
# 3438  👔የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር \n  -የራሱ መቆጣ...     MessageMediaPhoto
# 3439  🚫ቤትዎን ከአይጥ 🐀 ከበረሮ🕷 እና ከተባይ🐜 🚫\n               ...     MessageMediaPhoto
# 3440  😍  ታላቅ ቅናሽ 😍\nዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ\n...     MessageMediaPhoto
#
#                                    Preprocessed_Message
# 0     2 ሊትር ፔርሙስ ለቤት ለቢሮ ለሆቴል አገልግሎት መዋል የሚችሉ አሪፍ ፔር...
# 1     ቢላ ️ የስጋ የአጥንት 1000 ብር ለማዘዝ ውስን ፍሬ ነው የቀረው ጥራት...
# 2     2 ️ አንድ ብሩሽ እና አንድ ስፓቹላ ዋጋ 300 ብር ለማዘዝ ውስን ፍሬ ...
# 3     2 ️ አንድ ብሩሽ እና አንድ ስፓቹላ ዋጋ 300 ብር ውስን ፍሬ ነው የቀ...
# 4     የልብስ ማስጪያ ከአልሙኒየም የተሰራ የሚተጣጠፍ ለማስቀመጥ ቦታ የማይዝ ዋ...
# ...                                                 ...
# 3436  አስደሳች ዜና ብዙ ጊዜ በስራ ላይ የሚቆሙ ሰዎች የተረከዝ መሰነጣጠቅ እና...
# 3437  አስደሳች ዜና የፀጉር ማድረቂያ ️በጣልያን የሚመረት አንደኛ ደረጃ የፀጉር...
# 3438  የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር የራሱ መቆጣጠሪያ ያለ...
# 3439  ቤትዎን ከአይጥ ከበረሮ እና ከተባይ ነፃ ያድርጉ በቀላሉ በማንኛውም ሶኬት...
# 3440  ታላቅ ቅናሽ ዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ ባለ ዘጠኝ ...
#
# [3113 rows x 7 columns]

# %% [markdown]
# ### Task 2 : Label a Subset of Dataset in CoNLL Format

# %%
# Import EntityLabeler class
from scripts.data_labeling import EntityLabeler
# 1. Initialize the entity labeler
entity_labeler = EntityLabeler()

# 2. Generate CoNLL formatted string for messages from 0 to 50 (or any range dynamically)
start_message = 0
batch_size = 50  # You can adjust this to 50, 100, or any other size you want
conll_output = entity_labeler.create_conll_format(telegram_data, start_message, batch_size)


# # Generate for the next batch, for example 51-100
# start_message = 51
# batch_size = 50
# conll_output = entity_labeler.create_conll_format(telegram_data, start_message, batch_size)
# entity_labeler.save_conll_to_file(conll_output, f'telegram_data_conll_format_{start_message}_{start_message + batch_size}.txt')

# %% [markdown]
# ### Save the data in CoNLL format

# %%
# Save the generated output to a text file
entity_labeler.save_conll_to_file(conll_output, f'telegram_data_conll_format_{start_message}_{start_message + batch_size}.txt')
# Out:
# CoNLL format data has been saved to 'telegram_data_conll_format_0_50.txt'
